# %% [markdown]
# <a href="https://colab.research.google.com/github/crossboww/Machine_Learning/blob/main/ML_Projects/Diabetes_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('diabetes.csv')

# %%
data.shape
# Out:
# (768, 9)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# # Seperating the Features and Labels

# %%
x = data.drop(columns = 'Outcome', axis = 1)
y = data['Outcome']

# %%
print(x)
print(y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# # Spliting data in training and testing data

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify = y, random_state = 2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# # Standardization_Data

# %%
scaler = StandardScaler()

# %%
x_train_stand = scaler.fit_transform(x_train)
x_test_stand = scaler.transform(x_test)

# %%
print(x_train_stand)
# Out:
# [[-1.13796489 -0.07971099 -3.5556072  ...  0.02825037 -0.98159708
#   -0.7885233 ]
#  [ 0.64067858 -0.52091877  0.02549599 ... -0.17184452 -1.03823795
#    0.31879426]
#  [-0.84152431  2.12632792 -0.48609018 ... -0.25938604 -0.21545477
#    2.19271628]
#  ...
#  [ 2.12288146 -1.15121561  0.23013046 ... -0.25938604 -0.50760242
#    0.14843771]
#  [ 0.04779742 -0.30031488  0.43476492 ...  0.90366551 -0.69839272
#    0.40397253]
#  [-1.13796489 -1.11970076 -0.07682125 ...  0.45345201 -0.69243053
#   -0.70334503]]

# %%
X = x_train_stand
Y = y_train

# %%
print(X)
# Out:
# [[-1.13796489 -0.07971099 -3.5556072  ...  0.02825037 -0.98159708
#   -0.7885233 ]
#  [ 0.64067858 -0.52091877  0.02549599 ... -0.17184452 -1.03823795
#    0.31879426]
#  [-0.84152431  2.12632792 -0.48609018 ... -0.25938604 -0.21545477
#    2.19271628]
#  ...
#  [ 2.12288146 -1.15121561  0.23013046 ... -0.25938604 -0.50760242
#    0.14843771]
#  [ 0.04779742 -0.30031488  0.43476492 ...  0.90366551 -0.69839272
#    0.40397253]
#  [-1.13796489 -1.11970076 -0.07682125 ...  0.45345201 -0.69243053
#   -0.70334503]]

# %% [markdown]
# # Trainning the Model

# %%
classifier = svm.SVC(kernel = 'linear')

# %% [markdown]
# # Training the Support vector machine Classifier

# %%
classifier.fit(X,Y)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Accuracy Score on Training Data

# %%
X_train_prediction = classifier.predict(X)
Y_train_accuracy = accuracy_score(Y, X_train_prediction)

# %%
print('Accuracy Score the Training data : ' , Y_train_accuracy)
# Out:
# Accuracy Score the Training data :  0.7866449511400652

# %% [markdown]
# Accuracy Score on Testing Data

# %%
X_test_prediction = classifier.predict(x_test_stand)
Y_test_accuracy = accuracy_score(y_test, X_test_prediction)

# %%
print('Accuracy Score the Testing data : ' , Y_test_accuracy)
# Out:
# Accuracy Score the Testing data :  0.7727272727272727

# %% [markdown]
# # Making Predicting Sysytem

# %%
input_data = (8,99,84,0,0,35.4,0.388,50)

# Changing the input_data to numpy aaray
input_data_as_numpy_array = np.asarray(input_data)

# Reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# Standardize the input data
std_data = scaler.transform(input_data_reshaped)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)


if (prediction[0] == 0):
  print('The Person does not have Diabetes')
else:
  print('The Person have Diabetes')
# Out:
# [[ 1.23355973 -0.71000782  0.74171663 -1.29075209 -0.70188945  0.40342829
#   -0.24526575  1.42611182]]
# [0]
# The Person does not have Diabetes
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import joblib

# %%
joblib.dump(classifier, "diabetes_model.pkl ")
# Out:
# ['diabetes_model.pkl ']
