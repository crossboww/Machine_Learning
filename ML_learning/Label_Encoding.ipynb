# %% [markdown]
# <a href="https://colab.research.google.com/github/crossboww/Machine_Learning/blob/main/ML_learning/Label_Encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Label Encoding
#   - Converting the labels into numeric form

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
cancer_data = pd.read_csv('/content/breast_cancer_data.csv')

# %%
cancer_data.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
# Finding the Count of Different Labels
cancer_data['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# # Load Label Encoder function

# %%
label_encode = LabelEncoder()

# %%
labels = label_encode.fit_transform(cancer_data.diagnosis)

# %% [markdown]
# # Appending the Labels to the Dataframe

# %%
cancer_data['target'] = labels

# %%
cancer_data.head()
# Out:
#          id diagnosis  ...  Unnamed: 32  target
# 0    842302         M  ...          NaN       1
# 1    842517         M  ...          NaN       1
# 2  84300903         M  ...          NaN       1
# 3  84348301         M  ...          NaN       1
# 4  84358402         M  ...          NaN       1
#
# [5 rows x 34 columns]

# %% [markdown]
# 0 --> Benign
# 1 --> Malignant

# %%
cancer_data['target'].value_counts()
# Out:
# target
# 0    357
# 1    212
# Name: count, dtype: int64

# %% [markdown]
# # Encoding Labels for Iris Data

# %%
iris_data = pd.read_csv('/content/iris_data.csv')
iris_data.head()
iris_data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
label_encode_1 = LabelEncoder()

# %%
iris_data['iris_targer'] = label_encode_1.fit_transform(iris_data.Species)

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  ...  PetalWidthCm      Species iris_targer
# 0   1            5.1           3.5  ...           0.2  Iris-setosa           0
# 1   2            4.9           3.0  ...           0.2  Iris-setosa           0
# 2   3            4.7           3.2  ...           0.2  Iris-setosa           0
# 3   4            4.6           3.1  ...           0.2  Iris-setosa           0
# 4   5            5.0           3.6  ...           0.2  Iris-setosa           0
#
# [5 rows x 7 columns]

# %%
iris_data['iris_targer'].value_counts()
# Out:
# iris_targer
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64
