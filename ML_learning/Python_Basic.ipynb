# %% [markdown]
# <a href="https://colab.research.google.com/github/crossboww/Machine_Learning/blob/main/ML_learning/Python_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
print("machine Learning" + " " + "Project")
# Out:
# machine Learning Project

# %%
a = [ 2,3,4,5,65,45,45,32,34]
print(type(a))
# Out:
# <class 'list'>

# %%
my_slice= "Programing"
print(my_slice[0:8:2])
# Out:
# Porm

# %%
k= "krish konda"
print(k[1:6])
# Out:
# rish

# %%
word1= "Krish"
word2= "Konda"
print(word1+" "+word2)
# Out:
# Krish Konda
